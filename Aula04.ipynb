# %% [markdown]
# <a href="https://colab.research.google.com/github/Gus-2077/Aula_04_CTFE/blob/main/Aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exemplo - Estatística Descritiva**

# %%
A, B, C = input('').split()
A = float(A)
B = float(B)
C = float(C)
# Out:
# 5.0 6.0 7.0

# %%
PA = 2
PB = 3
PC = 5

# %%
media = (A*PA + B*PB + C*PC)/(PA+PB+PC)

print(f'MEDIA = {media:.1f}')
# Out:
# MEDIA = 6.3

# %% [markdown]
# # Exemplo - Cálculo de variância e desvio padrão

# %%
n1, n2, n3, n4 = input('Insira os numeros das distribuiçao: ').split()
n1 = int(n1)
n2 = int(n2)
n3 = int(n3)
n4 = int(n4)
# Out:
# Insira os numeros das distribuiçao: 11 10 11 8

# %%
# Media
media = (n1+n2+n3+n4)/4

# %%
# Desvios
d1 = n1 - media
d2 = n2 - media
d3 = n3 - media
d4 = n4 - media

# %%
# Somatória do quadrado dos desvios
soma = d1**2 + d2**2 + d3**2 + d4**2
# Variância da distribuição
variancia = soma/4

# %%
# Desvio Padrão
desvio_padrao = variancia**0.5

# %%
print(f'MEDIA = {media:.1f}')
print(f'VARIANCIA = {variancia:.1f}')
print(f'DESVIO PADRAO = {desvio_padrao:.1f}')
# Out:
# MEDIA = 10.0
# VARIANCIA = 1.5
# DESVIO PADRAO = 1.2
